# %%
import numpy as np

# %%
arr1 = np.array([[1,2,4],
               [8,0,1],
               [5,1,8]])

arr2 = np.array([[9,0,1],
                 [3,7,4],
                 [2,8,5]])

# %%
arr1.shape, arr2.shape
# Out:
# ((3, 3), (3, 3))

# %%
matMul = np.linalg.matmul(arr1, arr2)

# %%
matMul
# Out:
# array([[23, 46, 29],
#        [74,  8, 13],
#        [64, 71, 49]])

# %%
np.linalg.inv(arr1)
# Out:
# array([[ 0.01149425,  0.13793103, -0.02298851],
#        [ 0.67816092,  0.13793103, -0.35632184],
#        [-0.09195402, -0.10344828,  0.18390805]])

# %%
np.linalg.eigvals(arr1)
# Out:
# (3,)
